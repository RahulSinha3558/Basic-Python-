# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Sinha Rahul\Downloads\missing value 3558.csv",na_values="NaN")

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df.shape
# Out:
# (9, 4)

# %%
df.isnull()   # when true value indicate null value
# Out:
#     Date    Age  Sales    Day
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True  False
# 3  False  False  False   True
# 4  False   True   True  False
# 5  False  False   True  False
# 6  False   True   True   True
# 7  False  False  False  False
# 8  False  False  False  False

# %%
df[df.isnull()]
# Out:
#   Date  Age  Sales  Day
# 0  NaN  NaN    NaN  NaN
# 1  NaN  NaN    NaN  NaN
# 2  NaN  NaN    NaN  NaN
# 3  NaN  NaN    NaN  NaN
# 4  NaN  NaN    NaN  NaN
# 5  NaN  NaN    NaN  NaN
# 6  NaN  NaN    NaN  NaN
# 7  NaN  NaN    NaN  NaN
# 8  NaN  NaN    NaN  NaN

# %%
df.isnull().sum()
# Out:
# Date     0
# Age      3
# Sales    4
# Day      2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 9

# %% [markdown]
# # Filling Null value

# %%
df2= df.fillna(value = 0)
df2
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   0.0    9.0    Tuesday
# 2  01/10/2019  28.0    0.0  Wednesday
# 3  01/11/2019  32.0    7.0          0
# 4  01/12/2019   0.0    0.0     Monday
# 5  01/16/2019  32.0    0.0    Tuesday
# 6  01/17/2019   0.0    0.0          0
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df2.isnull().sum().sum()
# Out:
# 0

# %%
df3 = df.fillna(value = 20)
df3
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  20.0    9.0    Tuesday
# 2  01/10/2019  28.0   20.0  Wednesday
# 3  01/11/2019  32.0    7.0         20
# 4  01/12/2019  20.0   20.0     Monday
# 5  01/16/2019  32.0   20.0    Tuesday
# 6  01/17/2019  20.0   20.0         20
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # filling null value previous value

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df4 = df.fillna(method = "pad")
df4
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  32.0    9.0    Tuesday
# 2  01/10/2019  28.0    9.0  Wednesday
# 3  01/11/2019  32.0    7.0  Wednesday
# 4  01/12/2019  32.0    7.0     Monday
# 5  01/16/2019  32.0    7.0    Tuesday
# 6  01/17/2019  32.0    7.0    Tuesday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df5 = df.fillna(method = "bfill")
df5
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  28.0    9.0    Tuesday
# 2  01/10/2019  28.0    7.0  Wednesday
# 3  01/11/2019  32.0    7.0     Monday
# 4  01/12/2019  32.0    8.0     Monday
# 5  01/16/2019  32.0    8.0    Tuesday
# 6  01/17/2019  34.0    8.0   Thrusday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df6 = df.fillna(method = "bfill", axis = 1)
df6
# Out:
#          Date     Age      Sales        Day
# 0  01/01/2019    32.0        6.0     Monday
# 1  01/02/2019     9.0        9.0    Tuesday
# 2  01/10/2019    28.0  Wednesday  Wednesday
# 3  01/11/2019    32.0        7.0        NaN
# 4  01/12/2019  Monday     Monday     Monday
# 5  01/16/2019    32.0    Tuesday    Tuesday
# 6  01/17/2019     NaN        NaN        NaN
# 7  01/20/2019    34.0        8.0   Thrusday
# 8  01/21/2019    40.0       12.0    Tuesday

# %%
df7 = df.fillna(method = "pad", axis = 1)
df7
# Out:
#          Date         Age       Sales         Day
# 0  01/01/2019        32.0         6.0      Monday
# 1  01/02/2019  01/02/2019         9.0     Tuesday
# 2  01/10/2019        28.0        28.0   Wednesday
# 3  01/11/2019        32.0         7.0         7.0
# 4  01/12/2019  01/12/2019  01/12/2019      Monday
# 5  01/16/2019        32.0        32.0     Tuesday
# 6  01/17/2019  01/17/2019  01/17/2019  01/17/2019
# 7  01/20/2019        34.0         8.0    Thrusday
# 8  01/21/2019        40.0        12.0     Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %% [markdown]
# # fiiing different value in null in different columns

# %%
df8 = df.fillna({"Age" : 24,
                "Day" : "Tuesday"})
df8
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  24.0    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0    Tuesday
# 4  01/12/2019  24.0    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019  24.0    NaN    Tuesday
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %% [markdown]
# # filling null value the mean of a column

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df9 = df.fillna(value = df["Sales"].mean())
df9
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   8.4    9.0    Tuesday
# 2  01/10/2019  28.0    8.4  Wednesday
# 3  01/11/2019  32.0    7.0        8.4
# 4  01/12/2019   8.4    8.4     Monday
# 5  01/16/2019  32.0    8.4    Tuesday
# 6  01/17/2019   8.4    8.4        8.4
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df11 = df[["Sales","Age"]].fillna(value = df[["Sales","Age"]].max())
df11
# Out:
#    Sales   Age
# 0    6.0  32.0
# 1    9.0  40.0
# 2   12.0  28.0
# 3    7.0  32.0
# 4   12.0  40.0
# 5   12.0  32.0
# 6   12.0  40.0
# 7    8.0  34.0
# 8   12.0  40.0

# %%
df11 = df.fillna(value = df["Sales"].max())
df11
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  12.0    9.0    Tuesday
# 2  01/10/2019  28.0   12.0  Wednesday
# 3  01/11/2019  32.0    7.0       12.0
# 4  01/12/2019  12.0   12.0     Monday
# 5  01/16/2019  32.0   12.0    Tuesday
# 6  01/17/2019  12.0   12.0       12.0
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df17 = df.fillna(value = df["Sales"].max(),limit = 3)
df17
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  12.0    9.0    Tuesday
# 2  01/10/2019  28.0   12.0  Wednesday
# 3  01/11/2019  32.0    7.0       12.0
# 4  01/12/2019  12.0   12.0     Monday
# 5  01/16/2019  32.0   12.0    Tuesday
# 6  01/17/2019  12.0    NaN       12.0
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df12 = df.dropna()
df12
# Out:
#          Date   Age  Sales       Day
# 0  01/01/2019  32.0    6.0    Monday
# 7  01/20/2019  34.0    8.0  Thrusday
# 8  01/21/2019  40.0   12.0   Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df13 = df.dropna(how = "any")
df13
# Out:
#          Date   Age  Sales       Day
# 0  01/01/2019  32.0    6.0    Monday
# 7  01/20/2019  34.0    8.0  Thrusday
# 8  01/21/2019  40.0   12.0   Tuesday

# %%
df13 = df.dropna(how = "all")
df13
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/10/2019  28.0    NaN  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019   NaN    NaN     Monday
# 5  01/16/2019  32.0    NaN    Tuesday
# 6  01/17/2019   NaN    NaN        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %% [markdown]
# # replace

# %%
df15 = df.replace(to_replace = np.nan, value = 7890)
df15
# Out:
#          Date     Age   Sales        Day
# 0  01/01/2019    32.0     6.0     Monday
# 1  01/02/2019  7890.0     9.0    Tuesday
# 2  01/10/2019    28.0  7890.0  Wednesday
# 3  01/11/2019    32.0     7.0       7890
# 4  01/12/2019  7890.0  7890.0     Monday
# 5  01/16/2019    32.0  7890.0    Tuesday
# 6  01/17/2019  7890.0  7890.0       7890
# 7  01/20/2019    34.0     8.0   Thrusday
# 8  01/21/2019    40.0    12.0    Tuesday

# %%
df19 = df.replace(to_replace = np.nan, value = df.max())
df19
# Out:
# C:\Users\Sinha Rahul\AppData\Local\Temp\ipykernel_4348\2405517281.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df19 = df.replace(to_replace = np.nan, value = df.max())
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019  40.0    9.0    Tuesday
# 2  01/10/2019  28.0   12.0  Wednesday
# 3  01/11/2019  32.0    7.0        NaN
# 4  01/12/2019  40.0   12.0     Monday
# 5  01/16/2019  32.0   12.0    Tuesday
# 6  01/17/2019  40.0   12.0        NaN
# 7  01/20/2019  34.0    8.0   Thrusday
# 8  01/21/2019  40.0   12.0    Tuesday

# %%
df15 = df.replace(to_replace = np.nan, value = 7890)
df15
# Out:
#          Date     Age   Sales        Day
# 0  01/01/2019    32.0     6.0     Monday
# 1  01/02/2019  7890.0     9.0    Tuesday
# 2  01/10/2019    28.0  7890.0  Wednesday
# 3  01/11/2019    32.0     7.0       7890
# 4  01/12/2019  7890.0  7890.0     Monday
# 5  01/16/2019    32.0  7890.0    Tuesday
# 6  01/17/2019  7890.0  7890.0       7890
# 7  01/20/2019    34.0     8.0   Thrusday
# 8  01/21/2019    40.0    12.0    Tuesday

# %%
df16 = df.replace(to_replace = 32, value = 7890)
df16
# Out:
#          Date     Age  Sales        Day
# 0  01/01/2019  7890.0    6.0     Monday
# 1  01/02/2019     NaN    9.0    Tuesday
# 2  01/10/2019    28.0    NaN  Wednesday
# 3  01/11/2019  7890.0    7.0        NaN
# 4  01/12/2019     NaN    NaN     Monday
# 5  01/16/2019  7890.0    NaN    Tuesday
# 6  01/17/2019     NaN    NaN        NaN
# 7  01/20/2019    34.0    8.0   Thrusday
# 8  01/21/2019    40.0   12.0    Tuesday

# %% [markdown]
# # interpolate

# %%
df["Sales"] = df["Sales"].interpolate(methode = "linear")
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0   6.00     Monday
# 1  01/02/2019   NaN   9.00    Tuesday
# 2  01/10/2019  28.0   8.00  Wednesday
# 3  01/11/2019  32.0   7.00        NaN
# 4  01/12/2019   NaN   7.25     Monday
# 5  01/16/2019  32.0   7.50    Tuesday
# 6  01/17/2019   NaN   7.75        NaN
# 7  01/20/2019  34.0   8.00   Thrusday
# 8  01/21/2019  40.0  12.00    Tuesday

# %%
df["Sales"] = df["Sales"].interpolate(methode = "polynomial")
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0   6.00     Monday
# 1  01/02/2019   NaN   9.00    Tuesday
# 2  01/10/2019  28.0   8.00  Wednesday
# 3  01/11/2019  32.0   7.00        NaN
# 4  01/12/2019   NaN   7.25     Monday
# 5  01/16/2019  32.0   7.50    Tuesday
# 6  01/17/2019   NaN   7.75        NaN
# 7  01/20/2019  34.0   8.00   Thrusday
# 8  01/21/2019  40.0  12.00    Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0   6.00     Monday
# 1  01/02/2019   NaN   9.00    Tuesday
# 2  01/10/2019  28.0   8.00  Wednesday
# 3  01/11/2019  32.0   7.00        NaN
# 4  01/12/2019   NaN   7.25     Monday
# 5  01/16/2019  32.0   7.50    Tuesday
# 6  01/17/2019   NaN   7.75        NaN
# 7  01/20/2019  34.0   8.00   Thrusday
# 8  01/21/2019  40.0  12.00    Tuesday

# %%
df17 = df.fillna(method = "pad", axis = 0)
df17
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0   6.00     Monday
# 1  01/02/2019  32.0   9.00    Tuesday
# 2  01/10/2019  28.0   8.00  Wednesday
# 3  01/11/2019  32.0   7.00  Wednesday
# 4  01/12/2019  32.0   7.25     Monday
# 5  01/16/2019  32.0   7.50    Tuesday
# 6  01/17/2019  32.0   7.75    Tuesday
# 7  01/20/2019  34.0   8.00   Thrusday
# 8  01/21/2019  40.0  12.00    Tuesday

# %%
df18 = df.fillna(method = "pad", axis = 1)
df18
# Out:
#          Date         Age Sales        Day
# 0  01/01/2019        32.0   6.0     Monday
# 1  01/02/2019  01/02/2019   9.0    Tuesday
# 2  01/10/2019        28.0   8.0  Wednesday
# 3  01/11/2019        32.0   7.0        7.0
# 4  01/12/2019  01/12/2019  7.25     Monday
# 5  01/16/2019        32.0   7.5    Tuesday
# 6  01/17/2019  01/17/2019  7.75       7.75
# 7  01/20/2019        34.0   8.0   Thrusday
# 8  01/21/2019        40.0  12.0    Tuesday

# %%
df
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0   6.00     Monday
# 1  01/02/2019   NaN   9.00    Tuesday
# 2  01/10/2019  28.0   8.00  Wednesday
# 3  01/11/2019  32.0   7.00        NaN
# 4  01/12/2019   NaN   7.25     Monday
# 5  01/16/2019  32.0   7.50    Tuesday
# 6  01/17/2019   NaN   7.75        NaN
# 7  01/20/2019  34.0   8.00   Thrusday
# 8  01/21/2019  40.0  12.00    Tuesday
